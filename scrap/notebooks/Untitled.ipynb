# %%
import sqlite3
from sqlite3 import Error
import pandas as pd

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except Error as e:
        print(e)

    return conn

# %%
def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

# %%
database = 'data/db/articles.db'
sql_create_articles_table = """ CREATE TABLE IF NOT EXISTS articles (
                                    id text PRIMARY KEY,
                                    doi text,
                                    type text,
                                    published_date text,
                                    source text,
                                    title_words text,
                                    abstract_words text,
                                    abstract_sentences text
                                ); """

# create a database connection
conn = create_connection(database)

# create tables
if conn is not None:
    # create articles table
    create_table(conn, sql_create_articles_table)
else:
    print("Error! cannot create the database connection.")

# %%
df = context.catalog.load('prm_articles')
df.to_sql("articles_alchemy", "sqlite:///data/db/articles.db", if_exists="replace")
# Out:
# data/db/articles.db
#
#
# 2020-05-05 19:52:45,940 - kedro.io.data_catalog - INFO - Loading data from `prm_articles` (CSVDataSet)...

# %%
# Lets read from the table!
read = pd.read_sql('SELECT* FROM articles_alchemy', conn)
read.head()
# Out:
#                                      ID                               DOI  \
# 0        DOI:10.1016/j.ando.2020.04.005        10.1016/j.ando.2020.04.005
# 1       DOI:10.1016/j.jamda.2020.04.017       10.1016/j.jamda.2020.04.017
# 2  DOI:10.1016/j.fertnstert.2020.04.025  10.1016/j.fertnstert.2020.04.025
# 3      DOI:10.1016/j.neurol.2020.04.004      10.1016/j.neurol.2020.04.004
# 4       DOI:10.1016/j.jtcvs.2020.04.059       10.1016/j.jtcvs.2020.04.059
#
#                                                 Type  \
# 0                           Annales d'Endocrinologie
# 1  Journal of the American Medical Directors Asso...
# 2                            Fertility and Sterility
# 3                                 Revue Neurologique
# 4  The Journal of Thoracic and Cardiovascular Sur...
#
#                PublishedDate    Source  \
# 0  2020-04-21 00:00:00+00:00  ELSEVIER
# 1  2020-04-23 00:00:00+00:00  ELSEVIER
# 2  2020-04-16 00:00:00+00:00  ELSEVIER
# ...
